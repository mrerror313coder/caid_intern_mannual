# %%
# !pip install cohere
# Out:
# Collecting cohere
#   Downloading cohere-7.1.1-py3-none-any.whl.metadata (6.9 kB)
# Collecting fastavro<2.0.0,>=1.9.4 (from cohere)
#   Downloading fastavro-1.12.2-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.8 kB)
# Requirement already satisfied: httpx>=0.25.0 in /usr/local/lib/python3.13/dist-packages (from cohere) (0.28.1)
# Requirement already satisfied: pydantic>=1.9.2 in /usr/local/lib/python3.13/dist-packages (from cohere) (2.13.4)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.2 in /usr/local/lib/python3.13/dist-packages (from cohere) (2.46.4)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from cohere) (2.32.4)
# Requirement already satisfied: tokenizers<1,>=0.15 in /usr/local/lib/python3.13/dist-packages (from cohere) (0.23.1)
# Collecting types-requests<3.0.0,>=2.0.0 (from cohere)
#   Downloading types_requests-2.33.0.20260712-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: typing_extensions>=4.0.0 in /usr/local/lib/python3.13/dist-packages (from cohere) (4.16.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx>=0.25.0->cohere) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx>=0.25.0->cohere) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx>=0.25.0->cohere) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.13/dist-packages (from httpx>=0.25.0->cohere) (3.19)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx>=0.25.0->cohere) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic>=1.9.2->cohere) (0.8.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic>=1.9.2->cohere) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.0.0->cohere) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.0.0->cohere) (2.5.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /usr/local/lib/python3.13/dist-packages (from tokenizers<1,>=0.15->cohere) (1.28.0)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (8.5.0)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (3.32.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (1.6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (26.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (4.67.3)
# Downloading cohere-7.1.1-py3-none-any.whl (370 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 370.5/370.5 kB 6.9 MB/s eta 0:00:00
# Downloading fastavro-1.12.2-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 21.0 MB/s eta 0:00:00
# Downloading types_requests-2.33.0.20260712-py3-none-any.whl (21 kB)
# Installing collected packages: types-requests, fastavro, cohere
# Successfully installed cohere-7.1.1 fastavro-1.12.2 types-requests-2.33.0.20260712

# %%
import cohere
co = cohere.ClientV2("JVNvur73jskGr8rS98JubjUfi870n4ZLSavn5FCa")

# %%
def generate_text(message):
    response = co.chat_stream(model="command-a-plus-05-2026",
                              messages=[{'role': 'user', 'content': message}])

    for event in response:
        if event.type == "content-delta":
            text = event.delta.message.content.text
            if text:  # Only print if text is not None or empty
                print(text, end="")

# %%
generate_text("Generate a concise product description for the product: wireless earbuds.")
# Out:
# Experience crystal‑clear sound without the hassle of cords. These wireless earbuds deliver premium audio with active noise cancellation, a secure, all‑day fit, and up to 8 hours of playtime per charge—plus a charging case for up to 24 hours total. Seamlessly connect via Bluetooth, control music and calls with intuitive touch controls, and enjoy sweat‑resistant durability for workouts and daily use.

# %%
generate_text("""
    Generate a concise product description for the product: wireless earbuds.
    Use the following format: Hook, Solution, Features and Benefits, Call to Action.
    """)
# Out:
# **Hook**
# Experience premium sound without the cords—anytime, anywhere.
#
# **Solution**
# Wireless earbuds give you the freedom to move, work, and play without tangled wires, delivering studio‑quality audio and all‑day comfort.
#
# **Features and Benefits**
# - **True Wireless Freedom** – No cables, instant pairing for seamless use.
# - **High‑Fidelity Sound** – Dual drivers deliver clear highs, rich mids, and deep bass.
# - **Noise‑Cancellation** – Block out distractions for focused listening.
# - **Comfortable Fit** – Lightweight, ergonomic design with multiple ear tip sizes for a secure, all‑day wear.
# - **Long Battery Life** – Up to 8 hours per charge; charging case provides an additional 24 hours on the go.
# - **Touch Controls** – Play, pause, skip, and answer calls with a simple tap.
#
# **Call to Action**
# Upgrade your audio experience now—grab your wireless earbuds today!

# %%
generate_text("""
    Summarize this email in one sentence.
    Dear EnjoyTech,
    I am writing to thank you for your hard work and dedication in organizing our recent community meetup. The event was a great success and it would not have been possible without your efforts.
    I am especially grateful for the time and energy you have invested in making this event a reality. Your commitment to ensuring that everything ran smoothly and that our guests had a great time is greatly appreciated.
    I am also thankful for the support and guidance you have provided to me throughout the planning process. Your insights and ideas have been invaluable in ensuring that the event was a success.
    I am confident that our community will benefit greatly from this event and I am excited to see the positive impact it will have.
    Thank you again for your hard work and dedication. I am looking forward to working with you on future events.
    Sincerely,
    MR. ERROR 313
    """)
# Out:
# The sender thanks EnjoyTech for their hard work and dedication in organizing a successful community meetup and expresses appreciation for their support, insights, and looks forward to future collaborations.

# %%
generate_text("""
    Extract the movie title from the text below.
    Deadpool 2 | Official HD Deadpool's "Wet on Wet" Teaser | 2018
    """)
# Out:
# Deadpool 2

# %%
generate_text("""
    Given the following text, write down a list of potential frequently asked questions (FAQ), together with the answers.
    The Cohere Platform provides an API for developers and organizations to access cutting-edge LLMs without needing machine learning know-how.
    The platform handles all the complexities of curating massive amounts of text data, model development, distributed training, model serving, and more.
    This means that developers can focus on creating value on the applied side rather than spending time and effort on the capability-building side.

    There are two key types of language processing capabilities that the Cohere Platform provides — text generation and text embedding — and each is served by a different type of model.

    With text generation, we enter a piece of text, or prompt, and get back a stream of text as a completion to the prompt.
    One example is asking the model to write a haiku (the prompt) and getting an originally written haiku in return (the completion).

    With text embedding, we enter a piece of text and get back a list of numbers that represents its semantic meaning (we’ll see what “semantic” means in a section below).
    This is useful for use cases that involve “measuring” what a passage of text represents, for example, in analyzing its sentiment.
    """)
# Out:
# **Frequently Asked Questions (FAQ) – Cohere Platform**
#
# ---
#
# ### 1. What is the Cohere Platform?
# **Answer:**
# The Cohere Platform is a cloud‑based API that lets developers and organizations use state‑of‑the‑art large language models (LLMs) without any machine‑learning expertise. It manages all the heavy lifting—data curation, model development, distributed training, and model serving—so you can focus on building value‑adding applications.
#
# ---
#
# ### 2. Do I need machine‑learning knowledge to use the Cohere API?
# **Answer:**
# No. The platform abstracts away the complexities of building and maintaining LLMs. You only need to send text (prompts or inputs) and receive the model’s output (completions or embeddings).
#
# ---
#
# ### 3. What are the two main language‑processing capabilities offered by the platform?
# **Answer:**
# 1. **Text Generation** – Generates a continuation of a given prompt.
# 2. **Text Embedding** – Converts a piece of text into a numeric vector that captures its semantic meaning.
#
# ---
#
# ### 4. How does text generation work?
# **Answer:**
# You provide a prompt (any piece of text you want the model to continue). The model returns a stream of text that logically follows the prompt.
# *Example:* Prompt = “Write a haiku about sunrise.” → Completion = an original haiku about sunrise.
#
# ---
#
# ### 5. What is a text embedding and what is it used for?
# **Answer:**
# A text embedding is a list of numbers (a vector) that represents the semantic content of the input text. It enables “measuring” what a passage means, which is useful for tasks such as sentiment analysis, similarity searches, clustering, and recommendation systems.
#
# ---
#
# ### 6. Can I use both text generation and text embedding in the same application?
# **Answer:**
# Yes. Each capability is served by a different model type, so you can call whichever endpoint fits your use case—generation for creative or conversational tasks, embeddings for semantic analysis or search.
#
# ---
#
# ### 7. What are the practical benefits of using the Cohere Platform?
# **Answer:**
# - **Speed to market:** No need to build, train, or maintain your own models.
# - **Scalability:** Distributed training and serving handle massive workloads.
# - **Focus on application logic:** Developers spend time on value‑adding features rather than capability‑building.
# - **Access to cutting‑edge models:** Benefit from the latest research without internal expertise.
#
# ---
#
# ### 8. How do I get started with the Cohere API?
# **Answer:**
# 1. Sign up for an account on the Cohere dashboard.
# 2. Obtain an API key.
# 3. Make HTTP requests to the appropriate endpoint (e.g., `/generate` for text generation or `/embed` for embeddings) with your input text.
# 4. Process the returned completions or vectors in your application.
#
# ---
#
# ### 9. Is the platform suitable for enterprise use?
# **Answer:**
# Yes. The Cohere Platform is designed for both developers and organizations, offering robust, production‑grade infrastructure, secure API access, and the ability to handle large volumes of requests.
#
# ---
#
# ### 10. What kinds of applications can I build with the Cohere Platform?
# **Answer:**
# - Conversational chatbots and virtual assistants
# - Content creation (articles, poems, summaries)
# - Sentiment analysis and opinion mining
# - Semantic search and document retrieval
# - Personalization and recommendation engines
# - Automated customer support and FAQ generation
#
# These are just a few examples; the platform’s flexibility lets you integrate language understanding and generation into virtually any text‑centric product.
